# %% [markdown]
# <a href="https://colab.research.google.com/github/ZiyueNie/FM/blob/master/src/margin_call.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import csv

# %%
for n in ns:
    Omega= getData(n)
    mu_m=setting(Omega)
    w=optimalPortfolio(mu,Omega,mu_m)
    print(w)
    plt.bar(range(len(w)), w ,tick_label=names)
    plt.show()

# %%
stocks=['AMZN','FB','AAPL','JNJ','DOV','FIT','APD','TIF','net_liq_val']
MKT_0=[-500757,
-403973,
-403890,
102198,
-416197,
-394327,
101644,
-403974,
1044291]
net_liq_val_0=1044291
plt.bar(range(len(stocks)), MKT_0 ,tick_label=stocks)
plt.bar(8,net_liq_val_0,facecolor = 'yellowgreen')
'''for a,b in zip(range(len(stocks)), MKT_0): 
 plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=11) '''
plt.xlabel("stocks and net liquidation value") 
plt.ylabel("Market value") 
plt.title("2019/10/30 Initial Portfolio")
plt.show()

# %%
MKT_1=[-502795,
-183553,
-424950,
102067,
-417949,
-434392,
100659,
-406203,
983658
]
net_liq_val_1=983658
plt.bar(range(len(stocks)), MKT_1 ,tick_label=stocks)
plt.bar(8,net_liq_val_1,facecolor = 'yellowgreen')
'''for a,b in zip(range(len(stocks)), MKT_0): 
 plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=11) '''
plt.xlabel("stocks and net liquidation value") 
plt.ylabel("Market value") 
plt.title("2019/10/31 Portfolio")
plt.show()

# %%
MKT_2=[-256099,
-265357,
-217856,
101425,
-438996,
-501168,
100800,
-416433,
879940
]
net_liq_val_2=879940
plt.bar(range(len(stocks)), MKT_2 ,tick_label=stocks)
plt.bar(8,net_liq_val_2,facecolor = 'yellowgreen')
'''for a,b in zip(range(len(stocks)), MKT_0): 
 plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=11) '''
plt.xlabel("stocks and net liquidation value") 
plt.ylabel("Market value") 
plt.title("2019/11/1 Portfolio")
plt.show()

# %%
MKT_3=[-209353,
-246782,
-219330,
92984,
-450235,
-493436,
101206,
-418236,
868292
]
net_liq_val_3=868292
plt.bar(range(len(stocks)), MKT_3 ,tick_label=stocks)
plt.bar(8,net_liq_val_3,facecolor = 'yellowgreen')
'''for a,b in zip(range(len(stocks)), MKT_0): 
 plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=11) '''
plt.xlabel("stocks and net liquidation value") 
plt.ylabel("Market value") 
plt.title("2019/11/4 Portfolio")
plt.show()

# %%
MKT_4=[]

# %%
MKT_5=[]

# %%
stocks=['AMZN','FB','AAPL','JNJ','DOV','FIT','APD','TIF']
MKT=[-500757,
-403973,
-403890,
102198,
-416197,
-394327,
101644,
-403974]
net_liquidation_value=1044291
plt.bar(range(len(stocks)), MKT)
plt.bar(8,net_liquidation_value,tick_label=stocks,facecolor = 'yellowgreen')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-48d1220074bd> in <module>()
#      10 net_liquidation_value=1044291
#      11 plt.bar(range(len(stocks)), MKT)
# ---> 12 plt.bar(8,net_liquidation_value,tick_label=stocks,facecolor = 'yellowgreen')
#      13 plt.show()
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2438     return gca().bar(
#    2439         x, height, width=width, bottom=bottom, align=align,
# -> 2440         **({"data": data} if data is not None else {}), **kwargs)
#    2441
#    2442
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2479
#    2480         if tick_labels is not None:
# -> 2481             tick_labels = np.broadcast_to(tick_labels, len(patches))
#    2482             tick_label_axis.set_ticks(tick_label_position)
#    2483             tick_label_axis.set_ticklabels(tick_labels)
#
# <__array_function__ internals> in broadcast_to(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/stride_tricks.py in broadcast_to(array, shape, subok)
#     180            [1, 2, 3]])
#     181     """
# --> 182     return _broadcast_to(array, shape, subok=subok, readonly=True)
#     183
#     184
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/stride_tricks.py in _broadcast_to(array, shape, subok, readonly)
#     125     it = np.nditer(
#     126         (array,), flags=['multi_index', 'refs_ok', 'zerosize_ok'] + extras,
# --> 127         op_flags=['readonly'], itershape=shape, order='C')
#     128     with it:
#     129         # never really has writebackifcopy semantics
#
# ValueError: operands could not be broadcast together with remapped shapes [original->remapped]: (8,) and requested shape (1,)
